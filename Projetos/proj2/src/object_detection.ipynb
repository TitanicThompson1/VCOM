# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/ricardonunes/Documents/Universidade/4ano/VCOM/Projetos/proj2/src/object_detection.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ricardonunes/Documents/Universidade/4ano/VCOM/Projetos/proj2/src/object_detection.ipynb#ch0000000?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/home/ricardonunes/Documents/Universidade/4ano/VCOM/Projetos/proj2/src/object_detection.ipynb#ch0000000?line=1'>2</a> drive.mount("/content/gdrive")
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !git clone https://github.com/ultralytics/yolov5 # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12229, done.
# remote: Total 12229 (delta 0), reused 0 (delta 0), pack-reused 12229
# Receiving objects: 100% (12229/12229), 11.91 MiB | 5.70 MiB/s, done.
# Resolving deltas: 100% (8470/8470), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 27.6 MB/s
# Setup complete. Using torch 1.11.0+cu113 (Tesla T4)

# %%
# !python train.py --img 640 --cfg yolov5s.yaml --batch 32 --epochs 100 --data dataset.yaml --weights yolov5s.pt --workers 2 --name yolo_road_det
# Out:
# train: weights=yolov5s.pt, cfg=yolov5s.yaml, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=yolo_road_det, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-251-gc23a441 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --source "/content/gdrive/My Drive/dataset/images/test/" --weights runs/train/yolo_road_det/weights/best.pt --conf 0.25 --name yolo_road_det
# Out:
# detect: weights=['runs/train/yolo_road_det/weights/best.pt'], source=/content/gdrive/My Drive/dataset/images/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolo_road_det, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-251-gc23a441 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7020913 parameters, 0 gradients
# image 1/264 /content/gdrive/My Drive/dataset/images/test/road101.png: 320x640 1 speedlimit, Done. (0.023s)
# image 2/264 /content/gdrive/My Drive/dataset/images/test/road103.png: 512x640 1 speedlimit, Done. (0.017s)
# ...

# %%
# !python val.py --weights runs/train/yolo_road_det/weights/best.pt --data dataset.yaml
# Out:
# val: data=/content/yolov5/data/dataset.yaml, weights=['runs/train/yolo_road_det/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-251-gc23a441 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7020913 parameters, 0 gradients
# val: Scanning '/content/gdrive/My Drive/dataset/labels/test.cache' images and labels... 264 found, 0 missing, 0 empty, 0 corrupt: 100% 264/264 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:06<00:00,  1.41it/s]
#                  all        264        368      0.947      0.929      0.941      0.784
# ...

# %%
# !zip -r ./resultsyolo.zip ./runs/train/yolo_road_det/
# Out:
#   adding: runs/train/yolo_road_det/ (stored 0%)
#   adding: runs/train/yolo_road_det/P_curve.png (deflated 12%)
#   adding: runs/train/yolo_road_det/events.out.tfevents.1655080898.d19b754127d8.442.0 (deflated 35%)
#   adding: runs/train/yolo_road_det/results.csv (deflated 83%)
#   adding: runs/train/yolo_road_det/hyp.yaml (deflated 45%)
#   adding: runs/train/yolo_road_det/labels.jpg (deflated 26%)
#   adding: runs/train/yolo_road_det/val_batch2_labels.jpg (deflated 7%)
#   adding: runs/train/yolo_road_det/F1_curve.png (deflated 9%)
#   adding: runs/train/yolo_road_det/R_curve.png (deflated 11%)
#   adding: runs/train/yolo_road_det/train_batch2.jpg (deflated 4%)
#   adding: runs/train/yolo_road_det/labels_correlogram.jpg (deflated 29%)
#   adding: runs/train/yolo_road_det/val_batch2_pred.jpg (deflated 7%)
#   adding: runs/train/yolo_road_det/val_batch0_pred.jpg (deflated 17%)
#   adding: runs/train/yolo_road_det/train_batch0.jpg (deflated 4%)
# ...
